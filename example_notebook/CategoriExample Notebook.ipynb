# %% [markdown]
# ## Categorical Embedder
# ### Example

# %%
# Necessary imports
import categorical_embedder as ce

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Reading data
df = pd.read_csv('HR_Attrition_Data.csv')
df.shape
# Out:
# (54808, 14)

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
X = df.drop(['employee_id', 'is_promoted'], axis=1)
y = df['is_promoted']

# %%
# ce.get_embedding_info identifies the categorical variables, # of unique values and embedding size and returns a dictionary
embedding_info = ce.get_embedding_info(X)
embedding_info
# Out:
# {'department': (9, 5),
#  'region': (34, 17),
#  'education': (3, 2),
#  'gender': (2, 1),
#  'recruitment_channel': (3, 2)}

# %%
# ce.get_label_encoded_data integer encodes the categorical variables and prepares it to feed it to neural network
X_encoded,encoders = ce.get_label_encoded_data(X)
X_encoded.head()
# Out:
#    department  region  education  gender  recruitment_channel  \
# 0           7      31          2       0                    2
# 1           4      14          0       1                    0
# 2           7      10          0       1                    2
# 3           7      15          0       1                    0
# 4           8      18          0       1                    0
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
#
#    KPIs_met >80%  awards_won?  avg_training_score
# 0              1            0                  49
# 1              0            0                  60
# 2              0            0                  50
# 3              0            0                  50
# 4              0            0                  73

# %%
# splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X_encoded,y)

# ce.get_embeddings trains NN, extracts embeddings and return a dictionary containing the embeddings
embeddings = ce.get_embeddings(X_train, y_train, categorical_embedding_info=embedding_info, 
                            is_classification=True, epochs=100,batch_size=256)
# Out:
# HBox(children=(IntProgress(value=0, description='Training', style=ProgressStyle(description_width='initial')),…

# %%
embeddings
# Out:
# {'department': array([[ 0.44909748,  0.592682  , -0.2689146 , -0.6076638 , -0.47688553],
#         [ 0.14439532,  0.23831578, -0.09904855, -0.1884861 , -0.23708323],
#         [ 0.02280043,  0.14768346,  0.00430288, -0.05229405, -0.06076226],
#         [ 0.08651688,  0.33048603, -0.10082451, -0.24717978, -0.23439746],
#         [ 0.06930665,  0.26183563, -0.099448  , -0.22151738, -0.24915719],
#         [ 0.3246719 ,  0.13284945, -0.49051526, -0.13767388, -0.35033587],
#         [ 0.39557138,  0.6303038 , -0.31711328, -0.6432047 , -0.5024501 ],
#         [ 0.105141  ,  0.00382448, -0.16800691,  0.14332129, -0.09635292],
#         [ 0.5065225 ,  0.33804703, -0.4578551 , -0.3261275 , -0.34876052]],
#        dtype=float32),
#  'region': array([[ 0.06167015, -0.09331849, -0.00821102,  0.35873163,  0.27501398,
#          -0.18806422,  0.42246535,  0.16405596,  0.10364748, -0.01732335,
#           0.08967754, -0.4844684 ,  0.1706062 ,  0.07629129, -0.46060166,
#          -0.250795  , -0.20905156],
#         [ 0.15227915, -0.12810177,  0.04858813,  0.12176999,  0.24337043,
#          -0.29888666,  0.28821293,  0.16845648,  0.09924047, -0.07546613,
#           0.20567334, -0.1352939 ,  0.08037616,  0.11891732, -0.18827821,
#          -0.0816901 , -0.2779371 ],
#         [ 0.10410061, -0.2104857 ,  0.03398978,  0.44951865,  0.20713083,
#          -0.28150958,  0.16630962,  0.2176757 ,  0.15907326, -0.24305162,
#           0.13209617,  0.10084943,  0.16876855,  0.2158818 , -0.09895746,
#          -0.09712282, -0.21898103],
#         [ 0.03361392, -0.09406326,  0.09817785,  0.2577049 ,  0.30454093,
#          -0.18041614,  0.3392363 ,  0.27354133,  0.04589733, -0.05175021,
#           0.18609524, -0.30759484,  0.23998573,  0.05730164, -0.4153282 ,
#          -0.21307011, -0.15814604],
#         [ 0.15096396, -0.13050652,  0.12978545,  0.3539185 ,  0.25473082,
#          -0.15637578,  0.29674196,  0.25461993,  0.03402874, -0.15752971,
#           0.19972315, -0.03535189,  0.18373075,  0.06211969, -0.19313417,
#          -0.15184213, -0.24135719],
#         [ 0.29311594, -0.2278486 ,  0.10147502,  0.45177343,  0.24334185,
#          -0.2585309 ,  0.27289554,  0.3444534 , -0.11046959, -0.30788636,
#           0.28252742,  0.527343  ,  0.18462309,  0.10991604,  0.01184443,
#          -0.140023  , -0.29176837],
#         [ 0.22212954, -0.0972956 ,  0.0757604 ,  0.00119282,  0.10628817,
#          -0.04451968,  0.01875878,  0.04793382,  0.29772508, -0.13264635,
#           0.21271782, -0.420673  ,  0.14043371,  0.2398636 , -0.14792743,
#          -0.17283182, -0.13257244],
#         [ 0.22231904, -0.18607658,  0.10973643,  0.2119783 ,  0.24073566,
#          -0.18088289,  0.21400924,  0.18904465,  0.05207201, -0.21133952,
#           0.247929  ,  0.11467847,  0.21312265,  0.19659802, -0.10511905,
#          -0.21219096, -0.17890845],
#         [ 0.11948653, -0.13136931,  0.10426308,  0.3505519 ,  0.31600142,
#          -0.32948446,  0.30525216,  0.3088015 , -0.00783463, -0.22288117,
#           0.19944812,  0.05813633,  0.11685727,  0.13461244, -0.1513958 ,
#          -0.13962963, -0.33049056],
#         [ 0.02869872, -0.18674235,  0.17713551,  0.06570877,  0.16253975,
#          -0.14332786,  0.1743341 ,  0.05855466,  0.22767399, -0.09349857,
#           0.07442123, -0.38788933,  0.17868695,  0.25265324, -0.2979716 ,
#          -0.11825583, -0.03945841],
#         [ 0.37929267, -0.22558057,  0.29641664,  0.13798186,  0.17428468,
#          -0.16322204,  0.10453338,  0.18077698,  0.1327219 , -0.27045852,
#           0.2009385 ,  0.1341174 ,  0.14552666,  0.2806392 , -0.02933537,
#          -0.10095037, -0.17500046],
#         [ 0.409364  , -0.26337704,  0.21481998,  0.16067739,  0.15580739,
#          -0.3264027 ,  0.19733264,  0.27058062,  0.07919446, -0.4325755 ,
#           0.31672868,  0.647895  ,  0.1496081 ,  0.23755707,  0.04658863,
#          -0.06037766, -0.24323867]], dtype=float32),
#  'education': array([[-0.38068944,  0.28985274],
#         [-0.308726  ,  0.30023918],
#         [-0.18988381,  0.46631435]], dtype=float32),
#  'gender': array([[0.38233313],
#         [0.38486874]], dtype=float32),
#  'recruitment_channel': array([[-0.29799673,  0.37393624],
#         [-0.31355464,  0.3837454 ],
#         [-0.39704534,  0.2786043 ]], dtype=float32)}

# %%
# if you don't like the dictionary format; convert it to dataframe for easy readibility
dfs = ce.get_embeddings_in_dataframe(embeddings=embeddings, encoders=encoders)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))

# %%
dfs['department']
# Out:
#                    department_embedding_0  department_embedding_1  \
# Analytics                        0.449097                0.592682
# Finance                          0.144395                0.238316
# HR                               0.022800                0.147683
# Legal                            0.086517                0.330486
# Operations                       0.069307                0.261836
# Procurement                      0.324672                0.132849
# R&D                              0.395571                0.630304
# Sales & Marketing                0.105141                0.003824
# Technology                       0.506522                0.338047
#
#                    department_embedding_2  department_embedding_3  \
# Analytics                       -0.268915               -0.607664
# Finance                         -0.099049               -0.188486
# HR                               0.004303               -0.052294
# Legal                           -0.100825               -0.247180
# Operations                      -0.099448               -0.221517
# Procurement                     -0.490515               -0.137674
# R&D                             -0.317113               -0.643205
# Sales & Marketing               -0.168007                0.143321
# Technology                      -0.457855               -0.326127
#
#                    department_embedding_4
# Analytics                       -0.476886
# Finance                         -0.237083
# HR                              -0.060762
# Legal                           -0.234397
# Operations                      -0.249157
# Procurement                     -0.350336
# R&D                             -0.502450
# Sales & Marketing               -0.096353
# Technology                      -0.348761

# %%
dfs['education']
# Out:
#                   education_embedding_0  education_embedding_1
# Bachelor's                    -0.380689               0.289853
# Below Secondary               -0.308726               0.300239
# Master's & above              -0.189884               0.466314

# %%
# include these embeddings in your dataset:
data = ce.fit_transform(X, embeddings=embeddings, encoders=encoders, drop_categorical_vars=True)
data.head()
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
#
#    KPIs_met >80%  awards_won?  avg_training_score  department_embedding_0  \
# 0              1            0                  49                0.105141
# 1              0            0                  60                0.069307
# 2              0            0                  50                0.105141
# 3              0            0                  50                0.105141
# 4              0            0                  73                0.506522
#
#    department_embedding_1  department_embedding_2  ...  region_embedding_12  \
# 0                0.003824               -0.168007  ...             0.178687
# 1                0.261836               -0.099448  ...             0.196460
# 2                0.003824               -0.168007  ...             0.179156
# 3                0.003824               -0.168007  ...             0.137184
# 4                0.338047               -0.457855  ...             0.193554
#
#    region_embedding_13  region_embedding_14  region_embedding_15  \
# 0             0.252653            -0.297972            -0.118256
# 1             0.210553            -0.130724            -0.215601
# 2             0.165248            -0.212073            -0.186645
# 3             0.316768            -0.195833            -0.188082
# 4             0.230044            -0.097342            -0.129108
#
#    region_embedding_16  education_embedding_0  education_embedding_1  \
# 0            -0.039458              -0.189884               0.466314
# 1            -0.147089              -0.380689               0.289853
# 2            -0.157056              -0.380689               0.289853
# 3            -0.012853              -0.380689               0.289853
# 4            -0.080017              -0.380689               0.289853
#
#    gender_embedding_0  recruitment_channel_embedding_0  \
# 0            0.382333                        -0.397045
# 1            0.384869                        -0.297997
# 2            0.384869                        -0.397045
# 3            0.384869                        -0.297997
# 4            0.384869                        -0.297997
#
#    recruitment_channel_embedding_1
# 0                         0.278604
# 1                         0.373936
# 2                         0.278604
# 3                         0.373936
# 4                         0.373936
#
# [5 rows x 34 columns]
